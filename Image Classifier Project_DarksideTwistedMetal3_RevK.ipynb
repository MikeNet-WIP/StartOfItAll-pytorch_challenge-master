# %%
import torch
import os
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
# %matplotlib inline
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import json
import seaborn as sns
from PIL import Image
import copy
from collections import OrderedDict
from torch.optim import lr_scheduler
from torch.autograd import Variable
import operator
from torch.nn import init
import math
import torch.utils.model_zoo as model_zoo

starttime = time.time()


# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    print('CUDA is available!  Training on GPU.....Left, Square, Square, Square, Left ')
    
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# CUDA is available!  Training on GPU.....Left, Square, Square, Square, Left
# Time Stage: 0.001 seconds

# %% [markdown]
# break

# %%
def plotda_training(train_losses, valid_losses):
    #plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training loss')
    plt.plot(valid_losses, label='Validation loss')
    plt.xlabel('epochs')
    plt.legend(frameon=False)
    plt.title('Loss progress')
    ax.set_yscale('log')
    plt.figure(figsize=(15,24))
    plt.show()
    plt.savefig('progress.png')

# %%
def plotda_learning(scheduler_steps):
    #plt.subplot(1, 2, 1)
    plt.plot(scheduler_steps, label='LearningRate')
    plt.xlabel('epochs')
    plt.legend(frameon=False)
    plt.title('LearningRate progress')  
    ax.set_yscale('log')
    plt.figure(figsize=(15,24))
    plt.show()
    plt.savefig('LearningRate.png')

# %%
# define training and test data directories
data_dir = 'C:/PyTorch/flower_data/'
#data_dir = 'C:/PyTorch/flower_photos/'
train_dir = os.path.join(data_dir, 'train/')
valid_dir = os.path.join(data_dir, 'valid/')
test_dir = os.path.join(data_dir, 'test/')

dirs = {'train': train_dir, 
        'valid': valid_dir, 
        'test' : test_dir}

# %%
# load and transform data using ImageFolder

# VGG-16 Takes 224x224 images as input, so we resize all of them
train_transforms = transforms.Compose([transforms.RandomRotation(64),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                                                            [0.229, 0.224, 0.225])])

test_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],
                                                           [0.229, 0.224, 0.225])])

train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
valid_data = datasets.ImageFolder(valid_dir, transform=test_transforms)
test_data = datasets.ImageFolder(test_dir, transform=test_transforms)

# print out some data stats
print('Num training images: ', len(train_data))
print('Num valid images: ', len(valid_data))
print('Num test images: ', len(test_data))

# define dataloader parameters
batch_size = 14 #130 #30 #18
num_workers= 8
imagestoshow = 8#20#16
n_epochs1 = 60
n_epochs2 = 6
lr1min = 1e-08
lr1max = .006
lr2min = 1e-08
lr2max = 0.00008

# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
                                           num_workers=num_workers, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size, 
                                           num_workers=num_workers, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
                                          num_workers=num_workers, shuffle=True)
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Num training images:  6553
# Num valid images:  832
# Num test images:  817
# Time Stage: 5.306 seconds

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)
    
class_names = train_data.classes

sortedclasses = sorted(cat_to_name.items())
print(sortedclasses[0])
# Out:
# ('1', 'pink primrose')

# %% [markdown]
# ### Visualize a Batch of Training Data

# %%
# helper function to un-normalize and display an image
def imshow(img):

    img = img.transpose(1,2,0)
    img = img * np.array((0.229, 0.224, 0.225)) + np.array((0.485, 0.456, 0.406))
    img = img.clip(0, 1)

    plt.imshow(img)  # convert from Tensor image

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(15, 12))
# display 20 images
for idx in np.arange(imagestoshow):
    ax = fig.add_subplot(4, imagestoshow/4, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(sortedclasses[labels[idx]])
    
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Time Stage: 13.117 seconds

# %%
print(f"Time Stage Start: {(time.time() - starttime):.3f} seconds")
# Load the pretrained model from pytorch
model = models.densenet161(pretrained=True)
#print(model)


#model = xception(True)
# Freeze training for all "features" layers
for param in model.parameters():
    param.requires_grad = False
    
    
n_inputs = model.classifier.in_features
#n_inputs = model.classifier.in_features
#print(model.classifier.in_features) 
#print(model.classifier.out_features) 



#ClassifierNew(model)
classifier = nn.Sequential(OrderedDict([
                          ('dr', nn.Dropout(0.35)), 
                          ('fc2', nn.Linear(n_inputs, len(cat_to_name))),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))

model.classifier = classifier
#model.classifier = ClassifierNew()
#print(model)



# if GPU is available, move the model to GPU
if train_on_gpu:
    model.cuda()

criterion = nn.NLLLoss()


# specify optimizer (stochastic gradient descent) and learning rate = 0.001
#optimizer = optim.Adam(model.parameters(), lr=0.0006, betas=(0.9, 0.999), eps=1e-08, 
#                       weight_decay=1e-05, amsgrad=True)
#optimizer = optim.Adam(model.fc.parameters(), lr=lr1max, betas=(0.9, 0.999), eps=1e-08, 
#                       weight_decay=1e-04, amsgrad=True)
#optimizer = optim.Adam(model.parameters(), lr=lr1max, betas=(0.9, 0.999), eps=1e-08, 
#                       weight_decay=1e-04, amsgrad=True)
optimizer = optim.Adam(model.classifier.parameters(), lr=lr1max, betas=(0.9, 0.999), eps=1e-08, 
                       weight_decay=1e-04, amsgrad=True)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.10, patience=4, 
                                                 verbose=False, threshold=0.006, threshold_mode='rel', 
                                                 cooldown=0, min_lr=0, eps=1e-08)
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Time Stage Start: 16.087 seconds
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
#   nn.init.kaiming_normal(m.weight.data)
# Time Stage: 16.922 seconds

# %%
print(f"Time Stage Start: {(time.time() - starttime):.3f} seconds")


valid_loss_min = np.Inf # track change in validation loss

train_losses = []
valid_losses = []
scheduler_steps = []

for epoch in range(1, n_epochs1+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    start = time.time()
    
    ###################
    # train the model #
    ###################
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model.forward(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
    #    if batch_idx % 20 == 19:    # print training loss every specified number of mini-batches
     #       print('\t Epoch %d, Batch %d loss: %.16f' %
      #            (epoch, batch_idx + 1, train_loss / 20))
       #     print(f"\t \tTime per batch: {(time.time() - start)/3:.3f} seconds")
        #    train_loss = 0.0
        
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for batch_idx, (data, target) in enumerate(valid_loader):
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model.forward(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    scheduler.step(valid_loss)
    scheduler_steps.append(optimizer.param_groups[0]['lr'])
    if optimizer.param_groups[0]['lr'] <= lr1min:
        optimizer.param_groups[0]['lr']=lr1max
        
    #print('lr: {} '.format(optimizer.param_groups[0]['lr']))   
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tlr: {} '.format(
        epoch, train_loss, valid_loss, optimizer.param_groups[0]['lr']))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        #torch.save(model.state_dict(), 'model_augmented.pt')
        model.class_to_idx = train_data.class_to_idx
        #model.cpu()
        torch.save({'state_dict': model.state_dict(), 
                    'class_to_idx': model.class_to_idx}, 
                    'Project_DarksideRevKv1.pth')
        valid_loss_min = valid_loss
    
    print(f"Time per epoch: {(time.time() - start):.3f} seconds")
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Time Stage Start: 7.434 seconds
# Epoch: 1 	Training Loss: 2.869030 	Validation Loss: 0.891280 	lr: 0.006
# Validation loss decreased (inf --> 0.891280).  Saving model ...
# Time per epoch: 48.570 seconds
# Epoch: 2 	Training Loss: 1.936859 	Validation Loss: 0.474590 	lr: 0.006
# Validation loss decreased (0.891280 --> 0.474590).  Saving model ...
# Time per epoch: 46.664 seconds
# Epoch: 3 	Training Loss: 1.921622 	Validation Loss: 0.635008 	lr: 0.006
# Time per epoch: 46.922 seconds
# Epoch: 4 	Training Loss: 1.934313 	Validation Loss: 0.682909 	lr: 0.006
# Time per epoch: 46.676 seconds
# Epoch: 5 	Training Loss: 1.917650 	Validation Loss: 0.530273 	lr: 0.006
# Time per epoch: 45.740 seconds
# Epoch: 6 	Training Loss: 1.892439 	Validation Loss: 0.545402 	lr: 0.006
# Time per epoch: 45.340 seconds
# Epoch: 7 	Training Loss: 1.835839 	Validation Loss: 0.428743 	lr: 0.006
# Validation loss decreased (0.474590 --> 0.428743).  Saving model ...
# Time per epoch: 45.356 seconds
# Epoch: 8 	Training Loss: 1.788550 	Validation Loss: 0.565851 	lr: 0.006
# Time per epoch: 45.238 seconds
# Epoch: 9 	Training Loss: 1.839935 	Validation Loss: 0.553818 	lr: 0.006
# Time per epoch: 45.213 seconds
# Epoch: 10 	Training Loss: 1.847399 	Validation Loss: 0.665774 	lr: 0.006
# Time per epoch: 44.386 seconds
# Epoch: 11 	Training Loss: 1.871740 	Validation Loss: 0.655372 	lr: 0.006
# Time per epoch: 44.965 seconds
# Epoch: 12 	Training Loss: 1.879102 	Validation Loss: 0.517044 	lr: 0.0006000000000000001
# Time per epoch: 45.530 seconds
# Epoch: 13 	Training Loss: 1.266545 	Validation Loss: 0.311865 	lr: 0.0006000000000000001
# Validation loss decreased (0.428743 --> 0.311865).  Saving model ...
# Time per epoch: 45.941 seconds
# Epoch: 14 	Training Loss: 1.158543 	Validation Loss: 0.321863 	lr: 0.0006000000000000001
# Time per epoch: 45.563 seconds
# Epoch: 15 	Training Loss: 1.127708 	Validation Loss: 0.307656 	lr: 0.0006000000000000001
# Validation loss decreased (0.311865 --> 0.307656).  Saving model ...
# Time per epoch: 44.733 seconds
# Epoch: 16 	Training Loss: 1.016776 	Validation Loss: 0.288102 	lr: 0.0006000000000000001
# Validation loss decreased (0.307656 --> 0.288102).  Saving model ...
# Time per epoch: 44.154 seconds
# Epoch: 17 	Training Loss: 1.101736 	Validation Loss: 0.292122 	lr: 0.0006000000000000001
# Time per epoch: 45.907 seconds
# Epoch: 18 	Training Loss: 1.032890 	Validation Loss: 0.318919 	lr: 0.0006000000000000001
# Time per epoch: 45.176 seconds
# Epoch: 19 	Training Loss: 1.065485 	Validation Loss: 0.255849 	lr: 0.0006000000000000001
# Validation loss decreased (0.288102 --> 0.255849).  Saving model ...
# Time per epoch: 43.516 seconds
# Epoch: 20 	Training Loss: 1.135753 	Validation Loss: 0.317914 	lr: 0.0006000000000000001
# Time per epoch: 43.110 seconds
# Epoch: 21 	Training Loss: 1.044447 	Validation Loss: 0.325774 	lr: 0.0006000000000000001
# Time per epoch: 43.388 seconds
# Epoch: 22 	Training Loss: 1.098576 	Validation Loss: 0.302475 	lr: 0.0006000000000000001
# Time per epoch: 43.931 seconds
# Epoch: 23 	Training Loss: 1.007694 	Validation Loss: 0.320929 	lr: 0.0006000000000000001
# Time per epoch: 44.573 seconds
# Epoch: 24 	Training Loss: 1.033494 	Validation Loss: 0.319774 	lr: 6.000000000000001e-05
# Time per epoch: 44.135 seconds
# Epoch: 25 	Training Loss: 0.970030 	Validation Loss: 0.293446 	lr: 6.000000000000001e-05
# Time per epoch: 43.696 seconds
# Epoch: 26 	Training Loss: 1.007960 	Validation Loss: 0.270116 	lr: 6.000000000000001e-05
# Time per epoch: 43.568 seconds
# Epoch: 27 	Training Loss: 0.969077 	Validation Loss: 0.251811 	lr: 6.000000000000001e-05
# Validation loss decreased (0.255849 --> 0.251811).  Saving model ...
# Time per epoch: 43.709 seconds
# Epoch: 28 	Training Loss: 1.019182 	Validation Loss: 0.289583 	lr: 6.000000000000001e-05
# Time per epoch: 43.634 seconds
# Epoch: 29 	Training Loss: 0.972506 	Validation Loss: 0.264753 	lr: 6.000000000000001e-05
# Time per epoch: 43.025 seconds
# Epoch: 30 	Training Loss: 0.962647 	Validation Loss: 0.302515 	lr: 6.000000000000001e-05
# Time per epoch: 43.270 seconds
# Epoch: 31 	Training Loss: 1.027431 	Validation Loss: 0.269845 	lr: 6.000000000000001e-05
# Time per epoch: 43.268 seconds
# Epoch: 32 	Training Loss: 0.941626 	Validation Loss: 0.269918 	lr: 6.000000000000001e-06
# Time per epoch: 42.736 seconds
# Epoch: 33 	Training Loss: 0.904188 	Validation Loss: 0.277275 	lr: 6.000000000000001e-06
# Time per epoch: 42.599 seconds
# Epoch: 34 	Training Loss: 1.033923 	Validation Loss: 0.251914 	lr: 6.000000000000001e-06
# Time per epoch: 42.631 seconds
# Epoch: 35 	Training Loss: 0.975673 	Validation Loss: 0.251192 	lr: 6.000000000000001e-06
# Validation loss decreased (0.251811 --> 0.251192).  Saving model ...
# Time per epoch: 43.050 seconds
# Epoch: 36 	Training Loss: 1.021585 	Validation Loss: 0.290085 	lr: 6.000000000000001e-06
# Time per epoch: 42.922 seconds
# Epoch: 37 	Training Loss: 0.911506 	Validation Loss: 0.267706 	lr: 6.000000000000002e-07
# Time per epoch: 43.102 seconds
# Epoch: 38 	Training Loss: 0.962108 	Validation Loss: 0.248660 	lr: 6.000000000000002e-07
# Validation loss decreased (0.251192 --> 0.248660).  Saving model ...
# Time per epoch: 42.465 seconds
# Epoch: 39 	Training Loss: 0.978258 	Validation Loss: 0.268478 	lr: 6.000000000000002e-07
# Time per epoch: 41.776 seconds
# Epoch: 40 	Training Loss: 0.929782 	Validation Loss: 0.264640 	lr: 6.000000000000002e-07
# Time per epoch: 41.686 seconds
# Epoch: 41 	Training Loss: 0.950644 	Validation Loss: 0.276894 	lr: 6.000000000000002e-07
# Time per epoch: 41.604 seconds
# Epoch: 42 	Training Loss: 1.049727 	Validation Loss: 0.288418 	lr: 6.000000000000002e-07
# Time per epoch: 42.595 seconds
# Epoch: 43 	Training Loss: 0.926897 	Validation Loss: 0.273563 	lr: 6.000000000000002e-08
# Time per epoch: 42.286 seconds
# Epoch: 44 	Training Loss: 0.996859 	Validation Loss: 0.267424 	lr: 6.000000000000002e-08
# Time per epoch: 41.560 seconds
# Epoch: 45 	Training Loss: 0.906433 	Validation Loss: 0.285958 	lr: 6.000000000000002e-08
# Time per epoch: 41.717 seconds
# Epoch: 46 	Training Loss: 1.000928 	Validation Loss: 0.274989 	lr: 6.000000000000002e-08
# Time per epoch: 41.517 seconds
# Epoch: 47 	Training Loss: 0.969262 	Validation Loss: 0.279643 	lr: 6.000000000000002e-08
# Time per epoch: 42.450 seconds
# Epoch: 48 	Training Loss: 1.015884 	Validation Loss: 0.261391 	lr: 0.006
# Time per epoch: 42.776 seconds
# Epoch: 49 	Training Loss: 1.510492 	Validation Loss: 0.454692 	lr: 0.006
# Time per epoch: 43.682 seconds
# Epoch: 50 	Training Loss: 1.605777 	Validation Loss: 0.444965 	lr: 0.006
# Time per epoch: 44.505 seconds
# Epoch: 51 	Training Loss: 1.568814 	Validation Loss: 0.495659 	lr: 0.006
# Time per epoch: 44.173 seconds
# Epoch: 52 	Training Loss: 1.660540 	Validation Loss: 0.490953 	lr: 0.006
# Time per epoch: 44.006 seconds
# Epoch: 53 	Training Loss: 1.679278 	Validation Loss: 0.295376 	lr: 0.0006000000000000001
# Time per epoch: 44.012 seconds
# Epoch: 54 	Training Loss: 1.181710 	Validation Loss: 0.279168 	lr: 0.0006000000000000001
# Time per epoch: 43.904 seconds
# Epoch: 55 	Training Loss: 1.083061 	Validation Loss: 0.265917 	lr: 0.0006000000000000001
# Time per epoch: 43.886 seconds
# Epoch: 56 	Training Loss: 1.058230 	Validation Loss: 0.255959 	lr: 0.0006000000000000001
# Time per epoch: 44.275 seconds
# Epoch: 57 	Training Loss: 1.119285 	Validation Loss: 0.257407 	lr: 0.0006000000000000001
# Time per epoch: 44.075 seconds
# Epoch: 58 	Training Loss: 1.009471 	Validation Loss: 0.250468 	lr: 6.000000000000001e-05
# Time per epoch: 43.927 seconds
# Epoch: 59 	Training Loss: 1.029308 	Validation Loss: 0.261293 	lr: 6.000000000000001e-05
# Time per epoch: 44.094 seconds
# Epoch: 60 	Training Loss: 1.002601 	Validation Loss: 0.236824 	lr: 6.000000000000001e-05
# Validation loss decreased (0.248660 --> 0.236824).  Saving model ...
# Time per epoch: 44.130 seconds
# Time Stage: 2644.519 seconds

# %%
plotda_training(train_losses,valid_losses)
plotda_learning(scheduler_steps)

# %%
print(f"Time Stage Start: {(time.time() - starttime):.3f} seconds")
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(102))
class_total = list(0. for i in range(102))

model.eval()
# iterate over test data
for batch_idx, (data, target) in enumerate(test_loader):
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    #for i in range(20):
    for i in range (len(target.data)): 
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))


for i in range(102):
   if class_total[i] > 0:
       print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
           sortedclasses[i], 100 * class_correct[i] / class_total[i],
           np.sum(class_correct[i]), np.sum(class_total[i])))
   else:
       print('Test Accuracy of %5s: N/A (no training examples)' % (i))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
   100. * np.sum(class_correct) / np.sum(class_total),
   np.sum(class_correct), np.sum(class_total)))
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Time Stage Start: 2644.692 seconds
# Test Loss: 0.210908
#
# Test Accuracy of ('1', 'pink primrose'): 100% ( 5/ 5)
# Test Accuracy of ('10', 'globe thistle'): 100% ( 3/ 3)
# Test Accuracy of ('100', 'blanket flower'): 100% ( 8/ 8)
# Test Accuracy of ('101', 'trumpet creeper'): 100% ( 4/ 4)
# Test Accuracy of ('102', 'blackberry lily'): 100% ( 6/ 6)
# Test Accuracy of ('11', 'snapdragon'): 88% ( 8/ 9)
# Test Accuracy of ('12', "colt's foot"): 100% ( 9/ 9)
# Test Accuracy of ('13', 'king protea'): 100% ( 6/ 6)
# Test Accuracy of ('14', 'spear thistle'): 100% ( 3/ 3)
# Test Accuracy of ('15', 'yellow iris'): 100% ( 4/ 4)
# Test Accuracy of ('16', 'globe-flower'): 100% ( 3/ 3)
# Test Accuracy of ('17', 'purple coneflower'): 100% ( 9/ 9)
# Test Accuracy of ('18', 'peruvian lily'): 100% ( 6/ 6)
# Test Accuracy of ('19', 'balloon flower'): 100% ( 7/ 7)
# Test Accuracy of ('2', 'hard-leaved pocket orchid'): 100% ( 5/ 5)
# Test Accuracy of ('20', 'giant white arum lily'): 100% ( 3/ 3)
# Test Accuracy of ('21', 'fire lily'): 100% ( 2/ 2)
# Test Accuracy of ('22', 'pincushion flower'): 100% ( 4/ 4)
# Test Accuracy of ('23', 'fritillary'): 100% ( 7/ 7)
# Test Accuracy of ('24', 'red ginger'): 100% ( 2/ 2)
# Test Accuracy of ('25', 'grape hyacinth'): 100% ( 5/ 5)
# Test Accuracy of ('26', 'corn poppy'): 80% ( 4/ 5)
# Test Accuracy of ('27', 'prince of wales feathers'): 100% ( 3/ 3)
# Test Accuracy of ('28', 'stemless gentian'): 100% ( 6/ 6)
# Test Accuracy of ('29', 'artichoke'): 100% ( 9/ 9)
# Test Accuracy of ('3', 'canterbury bells'): 100% ( 2/ 2)
# Test Accuracy of ('30', 'sweet william'): 100% (14/14)
# Test Accuracy of ('31', 'carnation'): 100% ( 2/ 2)
# Test Accuracy of ('32', 'garden phlox'): 83% ( 5/ 6)
# Test Accuracy of ('33', 'love in the mist'): 100% ( 8/ 8)
# Test Accuracy of ('34', 'mexican aster'): 80% ( 4/ 5)
# Test Accuracy of ('35', 'alpine sea holly'): 100% ( 6/ 6)
# Test Accuracy of ('36', 'ruby-lipped cattleya'): 100% ( 7/ 7)
# Test Accuracy of ('37', 'cape flower'): 87% ( 7/ 8)
# Test Accuracy of ('38', 'great masterwort'): 100% ( 8/ 8)
# Test Accuracy of ('39', 'siam tulip'): 80% ( 4/ 5)
# Test Accuracy of ('4', 'sweet pea'): 50% ( 3/ 6)
# Test Accuracy of ('40', 'lenten rose'): 87% ( 7/ 8)
# Test Accuracy of ('41', 'barbeton daisy'): 100% (14/14)
# Test Accuracy of ('42', 'daffodil'): 100% ( 4/ 4)
# Test Accuracy of ('43', 'sword lily'): 81% (13/16)
# Test Accuracy of ('44', 'poinsettia'): 100% (11/11)
# Test Accuracy of ('45', 'bolero deep blue'): 66% ( 2/ 3)
# Test Accuracy of ('46', 'wallflower'): 100% (21/21)
# Test Accuracy of ('47', 'marigold'): 100% ( 3/ 3)
# Test Accuracy of ('48', 'buttercup'): 100% ( 5/ 5)
# Test Accuracy of ('49', 'oxeye daisy'): 100% ( 3/ 3)
# Test Accuracy of ('5', 'english marigold'): 100% ( 4/ 4)
# Test Accuracy of ('50', 'common dandelion'): 100% ( 8/ 8)
# Test Accuracy of ('51', 'petunia'): 83% (20/24)
# Test Accuracy of ('52', 'wild pansy'): 87% ( 7/ 8)
# Test Accuracy of ('53', 'primula'): 78% (11/14)
# Test Accuracy of ('54', 'sunflower'): 100% ( 4/ 4)
# Test Accuracy of ('55', 'pelargonium'): 100% ( 7/ 7)
# Test Accuracy of ('56', 'bishop of llandaff'): 100% ( 8/ 8)
# Test Accuracy of ('57', 'gaura'): 90% (10/11)
# Test Accuracy of ('58', 'geranium'): 100% (14/14)
# Test Accuracy of ('59', 'orange dahlia'): 100% ( 7/ 7)
# Test Accuracy of ('6', 'tiger lily'): 100% ( 7/ 7)
# Test Accuracy of ('60', 'pink-yellow dahlia'): 100% (10/10)
# Test Accuracy of ('61', 'cautleya spicata'): 100% ( 8/ 8)
# Test Accuracy of ('62', 'japanese anemone'): 100% ( 4/ 4)
# Test Accuracy of ('63', 'black-eyed susan'): 100% ( 4/ 4)
# Test Accuracy of ('64', 'silverbush'): 100% ( 5/ 5)
# Test Accuracy of ('65', 'californian poppy'): 100% ( 7/ 7)
# Test Accuracy of ('66', 'osteospermum'): 100% ( 4/ 4)
# Test Accuracy of ('67', 'spring crocus'): 100% ( 4/ 4)
# Test Accuracy of ('68', 'bearded iris'): 66% ( 2/ 3)
# Test Accuracy of ('69', 'windflower'): 100% ( 3/ 3)
# Test Accuracy of ('7', 'moon orchid'): 100% ( 6/ 6)
# Test Accuracy of ('70', 'tree poppy'): 100% ( 4/ 4)
# Test Accuracy of ('71', 'gazania'): 100% ( 9/ 9)
# Test Accuracy of ('72', 'azalea'): 100% (11/11)
# Test Accuracy of ('73', 'water lily'): 100% (28/28)
# Test Accuracy of ('74', 'rose'): 100% (14/14)
# Test Accuracy of ('75', 'thorn apple'): 100% (13/13)
# Test Accuracy of ('76', 'morning glory'): 100% ( 4/ 4)
# Test Accuracy of ('77', 'passion flower'): 100% (25/25)
# Test Accuracy of ('78', 'lotus lotus'): 100% (14/14)
# Test Accuracy of ('79', 'toad lily'): 100% ( 3/ 3)
# Test Accuracy of ('8', 'bird of paradise'): 100% (10/10)
# Test Accuracy of ('80', 'anthurium'): 100% (11/11)
# Test Accuracy of ('81', 'frangipani'): 100% (13/13)
# Test Accuracy of ('82', 'clematis'): 94% (16/17)
# Test Accuracy of ('83', 'hibiscus'): 100% (14/14)
# Test Accuracy of ('84', 'columbine'): 100% (10/10)
# Test Accuracy of ('85', 'desert-rose'): 90% ( 9/10)
# Test Accuracy of ('86', 'tree mallow'): 100% ( 5/ 5)
# Test Accuracy of ('87', 'magnolia'): 100% ( 6/ 6)
# Test Accuracy of ('88', 'cyclamen'): 100% (13/13)
# Test Accuracy of ('89', 'watercress'): 100% (15/15)
# Test Accuracy of ('9', 'monkshood'): 100% ( 2/ 2)
# Test Accuracy of ('90', 'canna lily'): 92% (13/14)
# Test Accuracy of ('91', 'hippeastrum'): 100% ( 8/ 8)
# Test Accuracy of ('92', 'bee balm'): 100% (11/11)
# Test Accuracy of ('93', 'ball moss'): 100% ( 6/ 6)
# Test Accuracy of ('94', 'foxglove'): 100% (16/16)
# Test Accuracy of ('95', 'bougainvillea'): 100% (14/14)
# Test Accuracy of ('96', 'camellia'): 88% ( 8/ 9)
# Test Accuracy of ('97', 'mallow'): 100% ( 5/ 5)
# Test Accuracy of ('98', 'mexican petunia'): 75% ( 3/ 4)
# Test Accuracy of ('99', 'bromelia'): 100% ( 7/ 7)
#
# Test Accuracy (Overall): 96% (788/817)
# Time Stage: 2652.340 seconds

# %%
print(f"Time Stage Start: {(time.time() - starttime):.3f} seconds")
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

if train_on_gpu:
    images = images.cpu()
images = images.numpy()

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(15, 16))
for idx in np.arange(imagestoshow):
    ax = fig.add_subplot(4, imagestoshow/4, idx+1, xticks=[], yticks=[])
    #plt.imshow(np.transpose(images[idx], (1, 2, 0)))
    imshow(images[idx])
    ax.set_title("{}\n {}".format(sortedclasses[preds[idx]], sortedclasses[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Time Stage Start: 2652.348 seconds
# Time Stage: 2656.375 seconds

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
print(f"Time Stage Start: {(time.time() - starttime):.3f} seconds")
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)

    model.load_state_dict(checkpoint['state_dict'])
    model.class_to_idx = checkpoint['class_to_idx']

    return model

#model = load_checkpoint('Project_DarksideRevKv1True.pth')
model = load_checkpoint('Project_DarksideRevKv1.pth')

for param in model.parameters():
    param.requires_grad = True
    
#optimizer = optim.Adam(model.parameters(), lr=0.00008, betas=(0.9, 0.999), eps=1e-08, 
#                       weight_decay=1e-04, amsgrad=True)
optimizer = optim.Adam(model.parameters(), lr=lr2max, betas=(0.9, 0.999), eps=1e-08, 
                       weight_decay=1e-04, amsgrad=True)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.10, patience=4, 
                                                 verbose=False, threshold=0.0008, threshold_mode='rel', 
                                                 cooldown=0, min_lr=0, eps=1e-08)
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Time Stage Start: 25.636 seconds
# Time Stage: 26.036 seconds

# %%
print(f"Time Stage Start: {(time.time() - starttime):.3f} seconds")
# number of epochs to train the model


valid_loss_min = np.Inf # track change in validation loss
train_losses2 = []
valid_losses2 = []

for epoch in range(1, n_epochs2+1):

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0
    start = time.time()
    
    ###################
    # train the model #
    ###################
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model.forward(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        train_loss += loss.item()*data.size(0)
    #    if batch_idx % 20 == 19:    # print training loss every specified number of mini-batches
     #       print('\t Epoch %d, Batch %d loss: %.16f' %
      #            (epoch, batch_idx + 1, train_loss / 20))
       #     print(f"\t \tTime per batch: {(time.time() - start)/3:.3f} seconds")
        #    train_loss = 0.0
        
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    for batch_idx, (data, target) in enumerate(valid_loader):
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model.forward(data)
        # calculate the batch loss
        loss = criterion(output, target)
        # update average validation loss 
        valid_loss += loss.item()*data.size(0)
    
    # calculate average losses
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
    scheduler.step(valid_loss)
    train_losses2.append(train_loss)
    valid_losses2.append(valid_loss)
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    scheduler_steps.append(optimizer.param_groups[0]['lr'])
    if optimizer.param_groups[0]['lr'] <= lr2min:
        optimizer.param_groups[0]['lr']=lr2max
    #print('lr: {} '.format(optimizer.param_groups[0]['lr']))   
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f} \tlr: {} '.format(
        epoch, train_loss, valid_loss, optimizer.param_groups[0]['lr']))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        #torch.save(model.state_dict(), 'model_augmented.pt')
        model.class_to_idx = train_data.class_to_idx
        #model.cpu()
        torch.save({'state_dict': model.state_dict(), 
                    'class_to_idx': model.class_to_idx}, 
                    'Project_DarksideRevKv1True.pth')
        valid_loss_min = valid_loss
    
    print(f"Time per epoch: {(time.time() - start):.3f} seconds")
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Time Stage Start: 2657.251 seconds
# Epoch: 1 	Training Loss: 1.102087 	Validation Loss: 0.311286 	lr: 8e-05
# Validation loss decreased (inf --> 0.311286).  Saving model ...
# Time per epoch: 157.095 seconds
# Epoch: 2 	Training Loss: 0.836038 	Validation Loss: 0.326508 	lr: 8e-05
# Time per epoch: 153.432 seconds
# Epoch: 3 	Training Loss: 0.667262 	Validation Loss: 0.294197 	lr: 8e-05
# Validation loss decreased (0.311286 --> 0.294197).  Saving model ...
# Time per epoch: 157.175 seconds
# Epoch: 4 	Training Loss: 0.573132 	Validation Loss: 0.138164 	lr: 8e-05
# Validation loss decreased (0.294197 --> 0.138164).  Saving model ...
# Time per epoch: 156.600 seconds
# Epoch: 5 	Training Loss: 0.474570 	Validation Loss: 0.117061 	lr: 8e-05
# Validation loss decreased (0.138164 --> 0.117061).  Saving model ...
# Time per epoch: 157.604 seconds
# Epoch: 6 	Training Loss: 0.449694 	Validation Loss: 0.114276 	lr: 8e-05
# Validation loss decreased (0.117061 --> 0.114276).  Saving model ...
# Time per epoch: 156.652 seconds
# Time Stage: 3595.816 seconds

# %%
plotda_training(train_losses,valid_losses)
plotda_training(train_losses2,valid_losses2)
plotda_learning(scheduler_steps)

# %%
print(f"Time Stage Start: {(time.time() - starttime):.3f} seconds")
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(102))
class_total = list(0. for i in range(102))

model.eval()
# iterate over test data
for batch_idx, (data, target) in enumerate(test_loader):
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)    
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    #for i in range(20):
    for i in range (len(target.data)): 
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))


for i in range(102):
   if class_total[i] > 0:
       print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
           sortedclasses[i], 100 * class_correct[i] / class_total[i],
           np.sum(class_correct[i]), np.sum(class_total[i])))
   else:
       print('Test Accuracy of %5s: N/A (no training examples)' % (i))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
   100. * np.sum(class_correct) / np.sum(class_total),
   np.sum(class_correct), np.sum(class_total)))
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Time Stage Start: 31.816 seconds
# Test Loss: 0.101987
#
# Test Accuracy of ('1', 'pink primrose'): 100% ( 5/ 5)
# Test Accuracy of ('10', 'globe thistle'): 100% ( 3/ 3)
# Test Accuracy of ('100', 'blanket flower'): 100% ( 8/ 8)
# Test Accuracy of ('101', 'trumpet creeper'): 100% ( 4/ 4)
# Test Accuracy of ('102', 'blackberry lily'): 100% ( 6/ 6)
# Test Accuracy of ('11', 'snapdragon'): 100% ( 9/ 9)
# Test Accuracy of ('12', "colt's foot"): 77% ( 7/ 9)
# Test Accuracy of ('13', 'king protea'): 100% ( 6/ 6)
# Test Accuracy of ('14', 'spear thistle'): 100% ( 3/ 3)
# Test Accuracy of ('15', 'yellow iris'): 100% ( 4/ 4)
# Test Accuracy of ('16', 'globe-flower'): 66% ( 2/ 3)
# Test Accuracy of ('17', 'purple coneflower'): 100% ( 9/ 9)
# Test Accuracy of ('18', 'peruvian lily'): 100% ( 6/ 6)
# Test Accuracy of ('19', 'balloon flower'): 100% ( 7/ 7)
# Test Accuracy of ('2', 'hard-leaved pocket orchid'): 100% ( 5/ 5)
# Test Accuracy of ('20', 'giant white arum lily'): 66% ( 2/ 3)
# Test Accuracy of ('21', 'fire lily'): 100% ( 2/ 2)
# Test Accuracy of ('22', 'pincushion flower'): 100% ( 4/ 4)
# Test Accuracy of ('23', 'fritillary'): 100% ( 7/ 7)
# Test Accuracy of ('24', 'red ginger'): 100% ( 2/ 2)
# Test Accuracy of ('25', 'grape hyacinth'): 100% ( 5/ 5)
# Test Accuracy of ('26', 'corn poppy'): 100% ( 5/ 5)
# Test Accuracy of ('27', 'prince of wales feathers'): 100% ( 3/ 3)
# Test Accuracy of ('28', 'stemless gentian'): 100% ( 6/ 6)
# Test Accuracy of ('29', 'artichoke'): 100% ( 9/ 9)
# Test Accuracy of ('3', 'canterbury bells'): 100% ( 2/ 2)
# Test Accuracy of ('30', 'sweet william'): 100% (14/14)
# Test Accuracy of ('31', 'carnation'): 100% ( 2/ 2)
# Test Accuracy of ('32', 'garden phlox'): 100% ( 6/ 6)
# Test Accuracy of ('33', 'love in the mist'): 100% ( 8/ 8)
# Test Accuracy of ('34', 'mexican aster'): 100% ( 5/ 5)
# Test Accuracy of ('35', 'alpine sea holly'): 100% ( 6/ 6)
# Test Accuracy of ('36', 'ruby-lipped cattleya'): 100% ( 7/ 7)
# Test Accuracy of ('37', 'cape flower'): 100% ( 8/ 8)
# Test Accuracy of ('38', 'great masterwort'): 100% ( 8/ 8)
# Test Accuracy of ('39', 'siam tulip'): 80% ( 4/ 5)
# Test Accuracy of ('4', 'sweet pea'): 66% ( 4/ 6)
# Test Accuracy of ('40', 'lenten rose'): 87% ( 7/ 8)
# Test Accuracy of ('41', 'barbeton daisy'): 100% (14/14)
# Test Accuracy of ('42', 'daffodil'): 75% ( 3/ 4)
# Test Accuracy of ('43', 'sword lily'): 100% (16/16)
# Test Accuracy of ('44', 'poinsettia'): 100% (11/11)
# Test Accuracy of ('45', 'bolero deep blue'): 100% ( 3/ 3)
# Test Accuracy of ('46', 'wallflower'): 100% (21/21)
# Test Accuracy of ('47', 'marigold'): 100% ( 3/ 3)
# Test Accuracy of ('48', 'buttercup'): 100% ( 5/ 5)
# Test Accuracy of ('49', 'oxeye daisy'): 100% ( 3/ 3)
# Test Accuracy of ('5', 'english marigold'): 100% ( 4/ 4)
# Test Accuracy of ('50', 'common dandelion'): 100% ( 8/ 8)
# Test Accuracy of ('51', 'petunia'): 95% (23/24)
# Test Accuracy of ('52', 'wild pansy'): 100% ( 8/ 8)
# Test Accuracy of ('53', 'primula'): 92% (13/14)
# Test Accuracy of ('54', 'sunflower'): 100% ( 4/ 4)
# Test Accuracy of ('55', 'pelargonium'): 100% ( 7/ 7)
# Test Accuracy of ('56', 'bishop of llandaff'): 100% ( 8/ 8)
# Test Accuracy of ('57', 'gaura'): 100% (11/11)
# Test Accuracy of ('58', 'geranium'): 100% (14/14)
# Test Accuracy of ('59', 'orange dahlia'): 100% ( 7/ 7)
# Test Accuracy of ('6', 'tiger lily'): 100% ( 7/ 7)
# Test Accuracy of ('60', 'pink-yellow dahlia'): 100% (10/10)
# Test Accuracy of ('61', 'cautleya spicata'): 100% ( 8/ 8)
# Test Accuracy of ('62', 'japanese anemone'): 100% ( 4/ 4)
# Test Accuracy of ('63', 'black-eyed susan'): 100% ( 4/ 4)
# Test Accuracy of ('64', 'silverbush'): 100% ( 5/ 5)
# Test Accuracy of ('65', 'californian poppy'): 100% ( 7/ 7)
# Test Accuracy of ('66', 'osteospermum'): 100% ( 4/ 4)
# Test Accuracy of ('67', 'spring crocus'): 100% ( 4/ 4)
# Test Accuracy of ('68', 'bearded iris'): 100% ( 3/ 3)
# Test Accuracy of ('69', 'windflower'): 100% ( 3/ 3)
# Test Accuracy of ('7', 'moon orchid'): 100% ( 6/ 6)
# Test Accuracy of ('70', 'tree poppy'): 100% ( 4/ 4)
# Test Accuracy of ('71', 'gazania'): 100% ( 9/ 9)
# Test Accuracy of ('72', 'azalea'): 100% (11/11)
# Test Accuracy of ('73', 'water lily'): 100% (28/28)
# Test Accuracy of ('74', 'rose'): 100% (14/14)
# Test Accuracy of ('75', 'thorn apple'): 100% (13/13)
# Test Accuracy of ('76', 'morning glory'): 100% ( 4/ 4)
# Test Accuracy of ('77', 'passion flower'): 100% (25/25)
# Test Accuracy of ('78', 'lotus lotus'): 100% (14/14)
# Test Accuracy of ('79', 'toad lily'): 100% ( 3/ 3)
# Test Accuracy of ('8', 'bird of paradise'): 100% (10/10)
# Test Accuracy of ('80', 'anthurium'): 100% (11/11)
# Test Accuracy of ('81', 'frangipani'): 100% (13/13)
# Test Accuracy of ('82', 'clematis'): 100% (17/17)
# Test Accuracy of ('83', 'hibiscus'): 100% (14/14)
# Test Accuracy of ('84', 'columbine'): 100% (10/10)
# Test Accuracy of ('85', 'desert-rose'): 100% (10/10)
# Test Accuracy of ('86', 'tree mallow'): 100% ( 5/ 5)
# Test Accuracy of ('87', 'magnolia'): 100% ( 6/ 6)
# Test Accuracy of ('88', 'cyclamen'): 100% (13/13)
# Test Accuracy of ('89', 'watercress'): 100% (15/15)
# Test Accuracy of ('9', 'monkshood'): 100% ( 2/ 2)
# Test Accuracy of ('90', 'canna lily'): 92% (13/14)
# Test Accuracy of ('91', 'hippeastrum'): 100% ( 8/ 8)
# Test Accuracy of ('92', 'bee balm'): 100% (11/11)
# Test Accuracy of ('93', 'ball moss'): 100% ( 6/ 6)
# Test Accuracy of ('94', 'foxglove'): 100% (16/16)
# Test Accuracy of ('95', 'bougainvillea'): 100% (14/14)
# Test Accuracy of ('96', 'camellia'): 77% ( 7/ 9)
# Test Accuracy of ('97', 'mallow'): 100% ( 5/ 5)
# Test Accuracy of ('98', 'mexican petunia'): 75% ( 3/ 4)
# Test Accuracy of ('99', 'bromelia'): 100% ( 7/ 7)
#
# Test Accuracy (Overall): 98% (802/817)
# Time Stage: 41.162 seconds

# %%
print(f"Time Stage Start: {(time.time() - starttime):.3f} seconds")
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

if train_on_gpu:
    images = images.cpu()
images = images.numpy()

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(15, 16))
for idx in np.arange(imagestoshow):
    ax = fig.add_subplot(4, imagestoshow/4, idx+1, xticks=[], yticks=[])
    #plt.imshow(np.transpose(images[idx], (1, 2, 0)))
    imshow(images[idx])
    ax.set_title("{}\n {}".format(sortedclasses[preds[idx]], sortedclasses[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Time Stage Start: 3603.833 seconds
# Time Stage: 3607.921 seconds

# %%
image_pathtet = os.path.join(data_dir, 'test/98/image_07758.jpg')
#imgtet = Image.open(image_pathtet)
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Time Stage: 5715.588 seconds

# %%
def process_image(image_path):
    ''' 
    Scales, crops, and normalizes a PIL image for a PyTorch       
    model, returns an Numpy array
    '''
    # Open the image
    img = Image.open(image_path)

    # Resize
    if img.size[0] > img.size[1]:
        img.thumbnail((5000, 256))
    else:
        img.thumbnail((256, 5000))

    # Crop 
    left_margin = (img.width-224)/2
    bottom_margin = (img.height-224)/2
    right_margin = left_margin + 224
    top_margin = bottom_margin + 224
    img = img.crop((left_margin, bottom_margin, right_margin, top_margin))
    
    # Normalize
    img = np.array(img)/255
    mean = np.array([0.485, 0.456, 0.406]) #Required mean
    std = np.array([0.229, 0.224, 0.225]) #Required std
    img = (img - mean)/std
    
    # Move color channels to first dimension as expected by PyTorch
    #img = img.numpy().transpose((2, 0, 1))
    img = img.transpose((2, 0, 1))
    
    return img

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
process_image(image_pathtet)
imshow(process_image(image_pathtet))
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# Time Stage: 5717.560 seconds

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
        # Process image
    img = process_image(image_path)
    
    # Numpy -> Tensor
    image_tensor = torch.from_numpy(img).type(torch.FloatTensor)

    # Add batch of size 1 to image
    model_input = image_tensor.unsqueeze(0)
    
    # Probs
    probs = torch.exp(model.forward(model_input))
    
    # Top probs
    top_probs, top_labs = probs.topk(topk)
    top_probs = top_probs.detach().numpy().tolist()[0] 
    top_labs = top_labs.detach().numpy().tolist()[0]
    
    # Convert indices to classes
    idx_to_class = {val: key for key, val in    
                                      model.class_to_idx.items()}

    top_labels = [idx_to_class[lab] for lab in top_labs]
    top_flowers = [cat_to_name[idx_to_class[lab]] for lab in top_labs]

    return top_probs, top_labels, top_flowers

# %%
probs, classes, flowers = predict(image_pathtet, model.cpu())
print(probs)
print(classes)
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# [0.6270265579223633, 0.3400920629501343, 0.019228043034672737, 0.013652641326189041, 5.832263241245528e-07]
# ['98', '19', '76', '1', '55']
# Time Stage: 5720.083 seconds

# %%
# TODO: Display an image along with the top 5 classes
def plot_solution(image_path, model):
    # Set up plot
    plt.figure(figsize = (6,10))
    ax = plt.subplot(2,1,1)

    # Set up title
    flower_num = image_path.split('/')[4]
    flowerClass = cat_to_name[flower_num]
    #print(flower_num)
    #print(flowerClass)
    # Plot flower
    img = process_image(image_path)
    #imshow(img, ax, title = title_);
    imshow(img, ax);
    #ax.set_title(flowerClass, color=("green"))
    #ax.set_title("{}-{}".format(flower_num, flowerClass), color=("green"))

    # Make prediction
    probs, labs, flowers = predict(image_path, model) 
    
    ax.set_title("{}-{}".format(flower_num, flowerClass), 
                 color=("green" if flower_num==labs[0] else "red"))

    # Plot bar chart
    plt.subplot(2,1,2)
    sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
    plt.show()

# %%
plot_solution(image_pathtet, model)
probs, labs, flowers = predict(image_pathtet, model)
print(probs)
print(labs)
print(flowers)
print(f"Time Stage: {(time.time() - starttime):.3f} seconds")
# Out:
# [0.6270265579223633, 0.3400920629501343, 0.019228043034672737, 0.013652641326189041, 5.832263241245528e-07]
# ['98', '19', '76', '1', '55']
# ['mexican petunia', 'balloon flower', 'morning glory', 'pink primrose', 'pelargonium']
# Time Stage: 5722.618 seconds
